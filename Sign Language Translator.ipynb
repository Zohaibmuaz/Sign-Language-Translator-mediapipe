# %% [markdown]
# # Sign Language Translator with MediaPipe and Transformers
#
# This notebook walks through the process of building a real-time sign language translator. We will use **MediaPipe** for hand and pose landmark detection and a **Transformer** model built with **TensorFlow/Keras** for gesture classification.

# %% [markdown]
# ## 1. Install and Import Dependencies

# %%
# !pip install tensorflow opencv-python mediapipe scikit-learn matplotlib

import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Layer, Dense, Dropout, LayerNormalization, MultiHeadAttention, Input
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %% [markdown]
# ## 2. Keypoints using MediaPipe Holistic
#
# We'll start by setting up the MediaPipe Holistic model. This powerful model can detect pose, face, and hand landmarks all at once. We'll also define some helper functions to process the video feed and draw the landmarks.

# %%
# Holistic model for pose, face, and hand tracking
mp_holistic = mp.solutions.holistic
# Drawing utilities to visualize landmarks
mp_drawing = mp.solutions.drawing_utils

def mediapipe_detection(image, model):
    """
    Takes an image and a MediaPipe model, processes the image, and returns the detection results.
    """
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

def draw_styled_landmarks(image, results):
    """
    Draws the detected landmarks on the image with custom styling.
    """
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             )
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             )
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             )
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# ## 3. Extract Keypoint Values
#
# This function will take the landmark data from MediaPipe and flatten it into a single NumPy array. This array will be the input feature for our model.

# %%
def extract_keypoints(results):
    """
    Extracts the coordinates of all landmarks into a single flattened NumPy array.
    """
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# ## 4. Setup Folders for Collection
#
# We need to create a directory structure to store our collected data. Each action will have its own folder, containing subfolders for each video sequence.

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data')

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
num_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Create folders for each action
for action in actions:
    for sequence in range(num_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# ## 5. Collect Keypoint Values for Training and Testing
#
# This is the data collection step. We'll use OpenCV to capture video from the webcam. For each sign, we'll record a number of sequences, and for each sequence, we'll save the keypoints for each frame.

# %% [markdown]
# ## 6. Preprocess Data and Create Labels and Features
#
# Now that we've collected the data, we need to load it from the saved `.npy` files, create corresponding labels, and split it into training and testing sets.

# %%
label_map = {label:num for num, label in enumerate(actions)}

sequences, labels = [], []
for action in actions:
    for sequence in range(num_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

X = np.array(sequences)
y = to_categorical(labels).astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# ## 7. Build the Transformer Model
#
# Here's the core of our project. We define a Transformer block, which includes multi-head attention and a feed-forward network. We also create a custom embedding layer that adds positional information to our input keypoints. Finally, we assemble these components into a Keras model.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Layer, Dense, Dropout, LayerNormalization, MultiHeadAttention, Input, GlobalAveragePooling1D
from tensorflow.keras.models import Model

class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super().__init__()
        if embed_dim % num_heads != 0:
            raise ValueError("embed_dim must be divisible by num_heads")
        # key_dim is size per head
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim // num_heads)
        self.ffn = tf.keras.Sequential(
            [
            Dense(ff_dim, activation="relu"),
            Dense(embed_dim)
            ]
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training=None):
        # Make `training` optional — Keras may call without it during model construction
        attn_output = self.att(inputs, inputs, training=training)  # self-attention
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

class TokenAndPositionEmbedding(Layer):
    def __init__(self, maxlen, embed_dim):
        super().__init__()
        self.proj = Dense(embed_dim)  # project raw numeric features to embed_dim
        self.pos_emb = tf.keras.layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        # x shape: (batch, seq_len, features)
        seq_len = tf.shape(x)[1]
        positions = tf.range(start=0, limit=seq_len, delta=1)
        pos_embeddings = self.pos_emb(positions)            # (seq_len, embed_dim)
        x = self.proj(x)                                   # (batch, seq_len, embed_dim)
        return x + pos_embeddings                          # broadcast add (batch, seq_len, embed_dim)

# -------------------------
# Build example model
# -------------------------
embed_dim = 64   # must be divisible by num_heads
num_heads = 4
ff_dim = 64
sequence_length = 30
num_keypoints = 1662  # your value

actions = np.array(['hello', 'thanks', 'iloveyou'])

inputs = Input(shape=(sequence_length, num_keypoints))
x = TokenAndPositionEmbedding(sequence_length, embed_dim)(inputs)
x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
x = GlobalAveragePooling1D()(x)
x = Dropout(0.1)(x)
x = Dense(20, activation="relu")(x)
x = Dropout(0.1)(x)
outputs = Dense(actions.shape[0], activation="softmax")(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 30, 1662)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ token_and_position_embedding_1  │ (None, 30, 64)         │       108,352 │
# │ (TokenAndPositionEmbedding)     │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_1             │ (None, 30, 64)         │        25,216 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 20)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │            63 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,931 (527.07 KB)
#  Trainable params: 134,931 (527.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 8. Train the Model
#
# Now we'll train our Transformer model. We'll use a `TensorBoard` callback to monitor the training process. The trained model weights will be saved to a file named `action.h5`.

# %%
log_dir = os.path.join('Logs')
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

# Check if a pre-trained model exists
if os.path.exists('action.h5'):
    print("Loading pre-trained model...")
    model.load_weights('action.h5')
else:
    print("Training new model...")
    model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
    model.save('action.h5')
# Out:
# Training new model...
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - categorical_accuracy: 0.3444 - loss: 1.4752
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.3366 - loss: 1.1078
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.3288 - loss: 1.1056
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.2720 - loss: 1.1019
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.3602 - loss: 1.1076
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.3131 - loss: 1.0947
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.2407 - loss: 1.1048
# Epoch 8/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.2896 - loss: 1.1019
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.3737 - loss: 1.0901
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.3562 - loss: 1.0927
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.3543 - loss: 1.0845
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.3073 - loss: 1.1043
# Epoch 13/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.4148 - loss: 1.0923
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.3795 - loss: 1.1023
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.3268 - loss: 1.1015
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.2505 - loss: 1.0919
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.3875 - loss: 1.1041
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.3210 - loss: 1.1063
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.4383 - loss: 1.0913
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.3699 - loss: 1.1021
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.2408 - loss: 1.1115
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.4266 - loss: 1.0807
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.3953 - loss: 1.1074
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.3679 - loss: 1.0855
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.4285 - loss: 1.0812
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.3268 - loss: 1.0934
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.4109 - loss: 1.0602
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3562 - loss: 1.0984
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.4031 - loss: 1.0654
# Epoch 30/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.4011 - loss: 1.0674
# Epoch 31/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.4306 - loss: 1.0764
# Epoch 32/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.3796 - loss: 1.0580
# Epoch 33/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.4580 - loss: 1.0461
# Epoch 34/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.4834 - loss: 1.0492
# Epoch 35/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.4539 - loss: 1.0346
# Epoch 36/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.3444 - loss: 1.0179
# Epoch 37/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.3269 - loss: 1.0711
# Epoch 38/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.4384 - loss: 1.0487
# Epoch 39/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.4677 - loss: 1.0007
# Epoch 40/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.4462 - loss: 1.0033
# Epoch 41/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.5323 - loss: 0.9879
# Epoch 42/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.4677 - loss: 0.9338
# Epoch 43/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.7261 - loss: 0.9581
# Epoch 44/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.5460 - loss: 0.9312
# Epoch 45/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.7123 - loss: 0.8618
# Epoch 46/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.6732 - loss: 0.8512
# Epoch 47/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.6321 - loss: 0.8216
# Epoch 48/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.6223 - loss: 0.7910
# Epoch 49/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.6986 - loss: 0.6950
# Epoch 50/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7045 - loss: 0.7409
# Epoch 51/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7201 - loss: 0.7088
# Epoch 52/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7045 - loss: 0.6900
# Epoch 53/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7025 - loss: 0.6077
# Epoch 54/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.7221 - loss: 0.6345
# Epoch 55/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.8004 - loss: 0.5378
# Epoch 56/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.7358 - loss: 0.5487
# Epoch 57/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.7318 - loss: 0.5875
# Epoch 58/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7515 - loss: 0.5930
# Epoch 59/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.7456 - loss: 0.5522
# Epoch 60/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.7358 - loss: 0.5058
# Epoch 61/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.7945 - loss: 0.4644
# Epoch 62/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8434 - loss: 0.4022
# Epoch 63/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.8043 - loss: 0.4256
# Epoch 64/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.7886 - loss: 0.4946
# Epoch 65/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.7573 - loss: 0.4452
# Epoch 66/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.8572 - loss: 0.3852
# Epoch 67/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.8062 - loss: 0.4076
# Epoch 68/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.8884 - loss: 0.3514
# Epoch 69/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.7808 - loss: 0.4528
# Epoch 70/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7945 - loss: 0.3971
# Epoch 71/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7809 - loss: 0.3990
# Epoch 72/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.8787 - loss: 0.3379
# Epoch 73/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.8786 - loss: 0.3031
# Epoch 74/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9100 - loss: 0.2766
# Epoch 75/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.9256 - loss: 0.2245
# Epoch 76/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9119 - loss: 0.2786
# Epoch 77/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9550 - loss: 0.1929
# Epoch 78/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.9041 - loss: 0.3119
# Epoch 79/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.9256 - loss: 0.2351
# Epoch 80/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.9198 - loss: 0.2122
# Epoch 81/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9628 - loss: 0.1519
# Epoch 82/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.8924 - loss: 0.2392
# Epoch 83/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.9198 - loss: 0.2072
# Epoch 84/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.8591 - loss: 0.3649
# Epoch 85/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.9022 - loss: 0.1948
# Epoch 86/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7613 - loss: 0.4759
# Epoch 87/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.7593 - loss: 0.6003
# Epoch 88/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.8826 - loss: 0.2916
# Epoch 89/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.8649 - loss: 0.3341
# Epoch 90/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.7770 - loss: 0.3469
# Epoch 91/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.8904 - loss: 0.2686
# Epoch 92/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.9687 - loss: 0.2310
# Epoch 93/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.9432 - loss: 0.2165
# Epoch 94/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.9100 - loss: 0.2313
# Epoch 95/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.9276 - loss: 0.1866
# Epoch 96/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9022 - loss: 0.2041
# Epoch 97/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.9237 - loss: 0.1875
# Epoch 98/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.9374 - loss: 0.1951
# Epoch 99/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9413 - loss: 0.1764
# Epoch 100/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.9139 - loss: 0.2012
# Epoch 101/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.9765 - loss: 0.0939
# Epoch 102/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9706 - loss: 0.0926
# Epoch 103/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.9530 - loss: 0.1118
# Epoch 104/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9648 - loss: 0.1014
# Epoch 105/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0593
# Epoch 106/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.9902 - loss: 0.0371
# Epoch 107/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.9824 - loss: 0.0455
# Epoch 108/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.9824 - loss: 0.0320
# Epoch 109/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.9902 - loss: 0.0221
# Epoch 110/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.9824 - loss: 0.0666
# Epoch 111/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 1.0000 - loss: 0.0254
# Epoch 112/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.9060 - loss: 0.2845
# Epoch 113/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.8453 - loss: 0.5839
# Epoch 114/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.8532 - loss: 0.4592
# Epoch 115/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.8003 - loss: 0.5625
# Epoch 116/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.8669 - loss: 0.3118
# Epoch 117/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.7632 - loss: 0.5711
# Epoch 118/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.9080 - loss: 0.2782
# Epoch 119/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.8317 - loss: 0.3358
# Epoch 120/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.9745 - loss: 0.1610
# Epoch 121/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.9335 - loss: 0.2450
# Epoch 122/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.9198 - loss: 0.1973
# Epoch 123/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9765 - loss: 0.0882
# Epoch 124/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.9745 - loss: 0.0945
# Epoch 125/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.9784 - loss: 0.0614
# Epoch 126/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 1.0000 - loss: 0.0645
# Epoch 127/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.9843 - loss: 0.0543
# Epoch 128/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9902 - loss: 0.0442
# Epoch 129/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.9902 - loss: 0.0234
# Epoch 130/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.9941 - loss: 0.0213
# Epoch 131/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 1.0000 - loss: 0.0173
# Epoch 132/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0214
# Epoch 133/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 1.0000 - loss: 0.0139
# Epoch 134/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 1.0000 - loss: 0.0146
# Epoch 135/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0116
# Epoch 136/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0093
# Epoch 137/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0049
# Epoch 138/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0096
# Epoch 139/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 1.0000 - loss: 0.0105
# Epoch 140/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - categorical_accuracy: 1.0000 - loss: 0.0075
# Epoch 141/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 1.0000 - loss: 0.0082
# Epoch 142/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0060
# Epoch 143/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 1.0000 - loss: 0.0073
# Epoch 144/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0057
# Epoch 145/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.9902 - loss: 0.0128
# Epoch 146/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0035
# Epoch 147/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0083
# Epoch 148/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0037
# Epoch 149/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 1.0000 - loss: 0.0162
# Epoch 150/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0133
# Epoch 151/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0054
# Epoch 152/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 1.0000 - loss: 0.0032
# Epoch 153/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 1.0000 - loss: 0.0027
# Epoch 154/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0058
# Epoch 155/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0071
# Epoch 156/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - categorical_accuracy: 1.0000 - loss: 0.0155
# Epoch 157/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 1.0000 - loss: 0.0030
# Epoch 158/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 1.0000 - loss: 0.0031
# Epoch 159/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 1.0000 - loss: 0.0020
# Epoch 160/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 1.0000 - loss: 0.0054
# Epoch 161/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 1.0000 - loss: 0.0024
# Epoch 162/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0080
# Epoch 163/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0026
# Epoch 164/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0047
# Epoch 165/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 1.0000 - loss: 0.0023
# Epoch 166/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 1.0000 - loss: 0.0126
# Epoch 167/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 1.0000 - loss: 0.0050
# Epoch 168/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0094
# Epoch 169/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 1.0000 - loss: 0.0014
# Epoch 170/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 1.0000 - loss: 0.0033
# Epoch 171/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0025
# Epoch 172/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0062
# Epoch 173/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 1.0000 - loss: 0.0036
# Epoch 174/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 1.0000 - loss: 0.0122
# Epoch 175/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 1.0000 - loss: 0.0016
# Epoch 176/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 1.0000 - loss: 0.0034
# Epoch 177/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 1.0000 - loss: 0.0032
# Epoch 178/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0021
# Epoch 179/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0110
# Epoch 180/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0026
# Epoch 181/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0175
# Epoch 182/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 1.0000 - loss: 0.0014
# Epoch 183/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 1.0000 - loss: 0.0014
# Epoch 184/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0019
# Epoch 185/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 1.0000 - loss: 0.0016
# Epoch 186/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0068
# Epoch 187/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 1.0000 - loss: 0.0058
# Epoch 188/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 1.0000 - loss: 0.0018
# Epoch 189/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0013
# Epoch 190/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0016
# Epoch 191/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0022
# Epoch 192/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 1.0000 - loss: 0.0020
# Epoch 193/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 1.0000 - loss: 0.0014
# Epoch 194/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0023
# Epoch 195/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0011
# Epoch 196/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - categorical_accuracy: 1.0000 - loss: 0.0024
# Epoch 197/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0020
# Epoch 198/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 1.0000 - loss: 0.0060
# Epoch 199/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 1.0000 - loss: 0.0012
# Epoch 200/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 1.0000 - loss: 0.0172
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 9. Make Predictions and Evaluate
#
# Let's evaluate the model's performance on the test data we set aside earlier. We'll look at the confusion matrix and the overall accuracy.

# %%
yhat = model.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

print("Confusion Matrix:\n", multilabel_confusion_matrix(ytrue, yhat))
print("Accuracy Score:", accuracy_score(ytrue, yhat))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Confusion Matrix:
#  [[[4 0]
#   [0 1]]
#
#  [[3 0]
#   [0 2]]
#
#  [[3 0]
#   [0 2]]]
# Accuracy Score: 1.0

# %% [markdown]
# ## 10. Test in Real Time
